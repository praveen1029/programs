# %% [markdown]
# # Observations & Findings
#
# 1) Of the four selected treatments - shown in the 'Quartiles, Outliers and Boxplots' cells, 'Capomulin' and 'Ramicane' helped reduce the tumor volume size more affectively, as highlighted in the boxplot below.
#
# ![image-2.png](attachment:image-2.png)
#
#
#
# 2) The number of mice used per drug treatment was not equal across the ten different drug treatments (including a placebo).
# - 'Capomulin', had the highest number of mice with: '230', while Zoniferol had the smallest mice number with '182' mice. Doesn't appear to directly affect the outcome of this study, but worth noting nonetheless.
#
# ![image.png](attachment:image.png)
#
# - After removing the duplicates the total number of mice was 249, with a near 50:50 gender split with  124 female mice to : 125 male mice - creating a level of parity.
#
# ![image-4.png](attachment:image-4.png)
#
#
# 3) The correlation between the mouse weight, and average tumor volume is 0.84. This demonstrates a high positive correlation between these two variables.  When the mouse weight increases (independent/ cause variable), the average tumor volume (dependent/ effect variable) is also likely to increase, with a 84% chance of this occuring.
#
#
# 4) Finally, the regression analysis helps us to better understand precisely how much the dependent variable (average tumor  volume size) is affected by the independent variable (weight of the mouse).         The R-squared value is 0.70, meaning that 70% of linear regression (image below), is relevant and fits in line with the data. 70% of the data is directly affected by correlation coefficient (red line below).
#
# ![image-5.png](attachment:image-5.png)
