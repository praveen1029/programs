# %%
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

# %%
df = pd.read_csv("BHARTIARTL.CSV") 
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-03-12  530.549988  532.750000  521.549988  524.200012  524.200012
# 1    2021-03-15  527.799988  527.799988  516.400024  522.849976  522.849976
# 2    2021-03-16  524.000000  533.750000  524.000000  529.299988  529.299988
# 3    2021-03-17  528.799988  531.000000  519.000000  522.900024  522.900024
# 4    2021-03-18  529.849976  532.200012  515.349976  527.200012  527.200012
# ..          ...         ...         ...         ...         ...         ...
# 244  2022-03-08  675.000000  686.849976  667.599976  683.000000  683.000000
# 245  2022-03-09  682.000000  698.000000  674.299988  691.500000  691.500000
# 246  2022-03-10  699.950012  707.500000  690.599976  697.750000  697.750000
# 247  2022-03-11  696.700012  702.400024  691.500000  694.849976  694.849976
# 248  2022-03-11  696.700012  702.400024  691.500000  694.849976  694.849976
#
#        Volume
# 0    11410264
# 1    10675512
# ...

# %%
fig, ax = plt.subplots(2,2)
ax[0,0].scatter(df["Open"],df["Low"])
ax[0,1].scatter(df["High"],df["Low"])
ax[1,0].scatter(df["Close"],df["Low"])
ax[1,1].scatter(df["Volume"],df["Low"])
fig.set_figheight(15)
fig.set_figwidth(15)
plt.show()

# %%
def predict_low_price(open, high):
    y = (0.62979*open) + (0.3438*high) + 5.73006
    print(y)

predict_low_price(530.549,532.75)

percentage = (521.549)/523.0239647099999  
percentage *100
# Out:
# 99.71799290099112

# %%
open = np.random.randint(500,1000,size = 500)
high = np.random.randint(500,1000,size = 500)

predict_low_price(open,high)
# Out:
# array([960.24681, 571.24302, 805.93536, 790.78095, 810.96822, 787.45311,
#        711.30294, 918.99387, 663.37224, 596.03301, 669.68817, 714.04449,
#        644.32281, 754.06746, 580.3947 , 577.35525, 767.08968, 917.98695,
#        644.42652, 658.7352 , 653.55984, 627.1998 , 716.18892, 698.74386,
#        757.60644, 823.64019, 638.99238, 844.52052, 910.95588, 779.11317,
#        899.42787, 562.88232, 598.98405, 596.13639, 615.58677, 820.83744,
#        861.49152, 768.33735, 688.99572, 883.46718, 727.7142 , 785.30463,
#        700.84611, 811.58544, 568.32531, 778.8486 , 680.33679, 764.33589,
#        780.10818, 677.22762, 828.92745, 818.82633, 732.74607, 674.08173,
#        838.30152, 806.23086, 720.7617 , 800.88513, 889.24785, 628.47162,
#        677.82342, 821.97528, 822.09123, 787.73571, 675.29508, 911.32995,
#        749.94558, 662.35581, 592.95411, 756.09999, 734.13963, 546.1395 ,
#        715.67814, 734.90373, 806.19141, 638.02797, 553.92516, 758.9541 ,
# ...
