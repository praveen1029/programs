# %%
import pandas as pd

# %%
# 1. Write a Python Pandas program to get the columns of the DataFrame . 

df = pd.read_csv("movie_metadata.csv",encoding='latin-1')
print(df.columns)
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'Unnamed: 24'],
#       dtype='object')

# %%
# 2. Write a Pandas program to get the information of the DataFrame including data types and memory usage. 

df = pd.read_csv("movie_metadata.csv",encoding='latin-1')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  50 non-null     bool
#  1   belongs_to_collection  10 non-null     object
#  2   budget                 50 non-null     int64
#  3   genres                 50 non-null     object
#  4   homepage               5 non-null      object
#  5   id                     50 non-null     int64
#  6   imdb_id                50 non-null     object
#  7   original_language      50 non-null     object
#  8   original_title         50 non-null     object
#  9   overview               49 non-null     object
#  10  popularity             50 non-null     object
#  11  poster_path            50 non-null     object
#  12  production_companies   50 non-null     object
#  13  production_countries   50 non-null     object
# ...

# %%
# 3. Write a Pandas program to get the details of the third movie of the DataFrame 

df = pd.read_csv("movie_metadata.csv",encoding='latin-1')
print(df[2:3])
# Out:
#    adult                              belongs_to_collection  budget  \
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...       0
#
#                                               genres homepage     id  \
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...      NaN  15602
#
#      imdb_id original_language    original_title  \
# 2  tt0113228                en  Grumpier Old Men
#
#                                             overview  ... revenue runtime  \
# 2  A family wedding reignites the ancient feud be...  ...       0     101
#
#                            spoken_languages    status  \
# 2  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline             title  video  \
# 2  Still Yelling. Still Fighting. Still Ready for...  Grumpier Old Men  FALSE
#
#   vote_average vote_count Unnamed: 24
# 2          6.5       92.0         NaN
#
# [1 rows x 25 columns]

# %%
# 4. Write a Pandas program to count the number of rows and columns of the DataFrame 

df = pd.read_csv("movie_metadata.csv",encoding='latin-1')
print("Number of rows:",len(df.index))
print("Number of column:",len(df.columns))
# Out:
# Number of rows: 50
# Number of column: 25

# %%
# 5. Write a Pandas program to get the details of the columns title and genres of the DataFrame. 

df = pd.read_csv("movie_metadata.csv",encoding='latin-1')
print(df["title"])
print(df["genres"])
# Out:
# 0                                             Toy Story
# 1                                               Jumanji
# 2                                      Grumpier Old Men
# 3                                     Waiting to Exhale
# 4                           Father of the Bride Part II
# 5                                                  Heat
# 6                                               Sabrina
# 7                                          Tom and Huck
# 8                                          Sudden Death
# 9                                             GoldenEye
# 10                               The American President
# 11                          Dracula: Dead and Loving It
# 12                                                Balto
# 13                                                Nixon
# 14                                     Cutthroat Island
# 15                                               Casino
# 16                                Sense and Sensibility
# ...

# %%
# 6. Write a Pandas program to get the details of the movie with title 'Grumpier Old Men'. 

df = pd.read_csv("movie_metadata.csv",encoding='latin-1')
print(df[df["title"]=="Grumpier Old Men"])
# Out:
#    adult                              belongs_to_collection  budget  \
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...       0
#
#                                               genres homepage     id  \
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...      NaN  15602
#
#      imdb_id original_language    original_title  \
# 2  tt0113228                en  Grumpier Old Men
#
#                                             overview  ... revenue runtime  \
# 2  A family wedding reignites the ancient feud be...  ...       0     101
#
#                            spoken_languages    status  \
# 2  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline             title  video  \
# 2  Still Yelling. Still Fighting. Still Ready for...  Grumpier Old Men  FALSE
#
#   vote_average vote_count Unnamed: 24
# 2          6.5       92.0         NaN
#
# [1 rows x 25 columns]

# %%
# 7. Write a Pandas program to get the details of  fifth movie of the DataFrame. 

df = pd.read_csv("movie_metadata.csv",encoding='latin-1')
print(df[4:5])
# Out:
#    adult                              belongs_to_collection  budget  \
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...       0
#
#                            genres homepage     id    imdb_id  \
# 4  [{'id': 35, 'name': 'Comedy'}]      NaN  11862  tt0113041
#
#   original_language               original_title  \
# 4                en  Father of the Bride Part II
#
#                                             overview  ...   revenue runtime  \
# 4  Just when George Banks has recovered from his ...  ...  76578911     106
#
#                            spoken_languages    status  \
# 4  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count Unnamed: 24
# 4  Father of the Bride Part II  FALSE          5.7      173.0         NaN
#
# [1 rows x 25 columns]

# %%
# 8. Write a Pandas program to create a smaller DataFrame with a subset of all features. 

df = pd.read_csv("movie_metadata.csv",encoding='latin-1')
subset = df[["id","title","budget","revenue","runtime"]]
print(subset)
# Out:
#         id                                              title    budget  \
# 0      862                                          Toy Story  30000000
# 1     8844                                            Jumanji  65000000
# 2    15602                                   Grumpier Old Men         0
# 3    31357                                  Waiting to Exhale  16000000
# 4    11862                        Father of the Bride Part II         0
# 5      949                                               Heat  60000000
# 6    11860                                            Sabrina  58000000
# 7    45325                                       Tom and Huck         0
# 8     9091                                       Sudden Death  35000000
# 9      710                                          GoldenEye  58000000
# 10    9087                             The American President  62000000
# 11   12110                        Dracula: Dead and Loving It         0
# ...

# %%
# 9. Write a Pandas program to display the first 10 rows of the DataFrame. 

df = pd.read_csv("movie_metadata.csv",encoding='latin-1')
print(df.head(10))
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
# 6  False                                                NaN  58000000
# 7  False                                                NaN         0
# 8  False                                                NaN  35000000
# 9  False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# ...

# %%
# 10. Write a Pandas program to sort the DataFrame based on release_date

df = pd.read_csv("movie_metadata.csv",encoding='latin-1')
df["date"] = pd.to_datetime(df["release_date"])
print(df.sort_values(by=["date"]))
# Out:
#     adult                              belongs_to_collection    budget  \
# 29  False                                                NaN         0
# 48  False                                                NaN         0
# 28  False                                                NaN  18000000
# 44  False                                                NaN  20000000
# 22  False                                                NaN  50000000
# 45  False                                                NaN  10000000
# 41  False                                                NaN  10000000
# 47  False  {'id': 136214, 'name': 'Pocahontas Collection'...  55000000
# 33  False  {'id': 9435, 'name': 'Babe Collection', 'poste...  30000000
# 49  False                                                NaN   6000000
# 38  False                                                NaN  12000000
# 34  False                                                NaN         0
# ...

# %%
# 11. Write a Pandas program to access those movies, released after 1995-01-01

df = pd.read_csv("movie_metadata.csv",encoding='latin-1')
print(df[df["release_date"]>"01-01-1995"])
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   False                                                NaN  65000000
# 2   False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   False                                                NaN  16000000
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5   False                                                NaN  60000000
# 6   False                                                NaN  58000000
# 7   False                                                NaN         0
# 8   False                                                NaN  35000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10  False                                                NaN  62000000
# 11  False                                                NaN         0
# ...

# %%
# 12. Write a Pandas program to sort movies on runtime in descending order. 

df = pd.read_csv("movie_metadata.csv",encoding='latin-1')
print(df.sort_values(by="runtime",ascending=False))
# Out:
#     adult                              belongs_to_collection    budget  \
# 13  False                                                NaN  44000000
# 15  False                                                NaN  52000000
# 5   False                                                NaN  60000000
# 16  False                                                NaN  16500000
# 22  False                                                NaN  50000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 31  False                                                NaN  29500000
# 46  False                                                NaN  33000000
# 3   False                                                NaN  16000000
# 6   False                                                NaN  58000000
# 21  False                                                NaN         0
# 25  False                                                NaN         0
# ...

# %%
# 13. Write a Pandas program to get those movies whose revenue more than 2 million and spent less than 1 million. 

df = pd.read_csv("movie_metadata.csv",encoding='latin-1')
revenue_df = df[df["revenue"]>2000000]
print(revenue_df[revenue_df["budget"]<1000000])
# Out:
#     adult                              belongs_to_collection  budget  \
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...       0
# 12  False  {'id': 117693, 'name': 'Balto Collection', 'po...       0
# 30  False                                                NaN       0
#
#                                                genres homepage     id  \
# 4                      [{'id': 35, 'name': 'Comedy'}]      NaN  11862
# 12  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...      NaN  21032
# 30  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...      NaN   9909
#
#       imdb_id original_language               original_title  \
# 4   tt0113041                en  Father of the Bride Part II
# 12  tt0112453                en                        Balto
# 30  tt0112792                en              Dangerous Minds
#
#                                              overview  ...  release_date  \
# 4   Just when George Banks has recovered from his ...  ...    10-02-1995
# ...

# %%
# 14. Write a Pandas program to get the longest runtime and shortest runtime 

df = pd.read_csv("movie_metadata.csv",encoding='latin-1')
print("Longest runtime:",df["runtime"].max())
print("Shortest runtime:",df["runtime"].min())
# Out:
# Longest runtime: 192
# Shortest runtime: 50

# %%
# 15. Write a Pandas program to calculate the number of votes garnered by the 70% movie. 

df = pd.read_csv("movie_metadata.csv",encoding='latin-1')
print(df['vote_count'].quantile(0.70))
# Out:
# 402.69999999999993

# %%
# 16. Write a Pandas program to display the movies (title, runtime) longer than 30 minutes and shorter than 360 minutes. 

df = pd.read_csv("movie_metadata.csv",encoding='latin-1')
runtime_df = df[['title', 'runtime']]
print(runtime_df[(runtime_df['runtime'] >= 30) & (runtime_df['runtime'] <= 360)])
# Out:
#                              title  runtime
# 0                        Toy Story       81
# 1                          Jumanji      104
# 2                 Grumpier Old Men      101
# 3                Waiting to Exhale      127
# 4      Father of the Bride Part II      106
# 5                             Heat      170
# 6                          Sabrina      127
# 7                     Tom and Huck       97
# 8                     Sudden Death      106
# 9                        GoldenEye      130
# 10          The American President      106
# 11     Dracula: Dead and Loving It       88
# 12                           Balto       78
# 13                           Nixon      192
# 14                Cutthroat Island      119
# 15                          Casino      178
# 16           Sense and Sensibility      136
# 17                      Four Rooms       98
# 18  Ace Ventura: When Nature Calls       90
# 19                     Money Train      103
# ...

# %%
# 17. Write a Pandas program to display the movies (title, number of votes) that received specified number of votes. 

df = pd.read_csv("movie_metadata.csv",encoding='latin-1')
n = 300
count_df = df[['title', 'vote_count']]
print(count_df[count_df['vote_count'] >= n])
# Out:
#                              title  vote_count
# 0                        Toy Story        5415
# 1                          Jumanji        2413
# 5                             Heat        1886
# 9                        GoldenEye        1194
# 12                           Balto         423
# 15                          Casino        1343
# 16           Sense and Sensibility         364
# 17                      Four Rooms         539
# 18  Ace Ventura: When Nature Calls        1128
# 20                      Get Shorty         305
# 22                       Assassins         394
# 24               Leaving Las Vegas         365
# 28       The City of Lost Children         308
# 31                  Twelve Monkeys        2470
# 33                            Babe         756
# 35                Dead Man Walking         350
# 38                        Clueless         828
# 43                   Mortal Kombat         452
# 46                           Se7en        5915
# ...
